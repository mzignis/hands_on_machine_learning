# %% [markdown]
# ### Polynomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
m = 100
X = 3 * np.random.randn(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([0.82839185]), array([[-2.44532903]]))

# %%
X_pred = np.arange(-10, 6, 0.1)
X_pred = X_pred[:, np.newaxis]

# %%
y_pred = lin_reg.predict(X_pred)

# %%
plt.scatter(X, y, alpha=0.75)
plt.plot(X_pred, y_pred, c='r', lw=2)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_feat = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_feat.fit_transform(X)
X[0], X_poly[0]
# Out:
# (array([-2.10132105]), array([-2.10132105,  4.41555014]))

# %%
lin_reg_poly = LinearRegression()
lin_reg_poly.fit(X_poly, y)
lin_reg_poly.intercept_, lin_reg_poly.coef_
# Out:
# (array([2.2042664]), array([[1.06521001, 0.50838707]]))

# %%
X_pred_poly = poly_feat.fit_transform(X_pred)
y_pred_poly = lin_reg_poly.predict(X_pred_poly)

# %%
plt.scatter(X, y, alpha=0.75)
plt.plot(X_pred, y_pred, c='r', lw=2)
plt.plot(X_pred, y_pred_poly, c='g', lw=2)
plt.show()

# %% [markdown]
# #### Poly 10-deg

# %%
poly_feat_10 = PolynomialFeatures(degree=10, include_bias=False)
X_poly_10 = poly_feat_10.fit_transform(X)
X[0], X_poly_10[0]
# Out:
# (array([-2.10132105]),
#  array([  -2.10132105,    4.41555014,   -9.27848844,   19.49708304,
#          -40.96963094,   86.09034775, -180.90345963,  380.13624709,
#         -798.78829653, 1678.51065914]))

# %%
lin_reg_poly_10 = LinearRegression()
lin_reg_poly_10.fit(X_poly_10, y)
lin_reg_poly_10.intercept_, lin_reg_poly_10.coef_
# Out:
# (array([2.0663754]), array([[ 7.47626969e-01,  5.64056636e-01,  1.36038174e-01,
#           2.72274769e-02, -7.68702508e-03, -3.56079566e-03,
#          -4.87575515e-04, -2.33548337e-05,  3.14382370e-07,
#           4.20354612e-08]]))

# %%
X_pred_poly_10 = poly_feat_10.fit_transform(X_pred)
y_pred_poly_10 = lin_reg_poly_10.predict(X_pred_poly_10)

# %%
plt.scatter(X, y, alpha=0.75)
plt.plot(X_pred, y_pred, c='r', lw=2)
plt.plot(X_pred, y_pred_poly, c='g', lw=2)
plt.plot(X_pred, y_pred_poly_10, c='gold', lw=2)
plt.ylim(-10, 60)
plt.show()
