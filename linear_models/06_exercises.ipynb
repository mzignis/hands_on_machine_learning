# %% [markdown]
# ## 1. What Linear Regression training algorithm can you use if you have a training set with millions of features?
#
#
# The best one is: <b> Stochastic GD </b> or <b> Mini-batch GD </b>
#
# <br>
#
# Algorithm | Large numer of instances (m) | Large numer of feature (n) | Scaling req. | sklearn
# ---|---|---|---|---
# NE | Fast | Slow | False | LinearRegression
# Batch GD | Slow | Fast | True | ---
# Stochastic GD | Fast | Fast | True | SGDRegressor
# Mini-batch GD | Fast | Fast | True | ---

# %% [markdown]
# ## 2. Suppose the features in your training set have very different scales. What algorithms might suffer from this, and how? What can you do about it?
#
# - Batch GD, Stochastic GD, Mini-batch GD
# - need to use some preprocessing methods, for example: Standard Scaling or Normalizer

# %% [markdown]
# ## 3. Can Gradient Descent get stuck in a local minimum when training a Logistic Regression model?
#
# No because cost function is covex - $\sigma(t)$

# %% [markdown]
# ## 4. Do all Gradient Descent algorithms lead to the same model provided you let them run long enough?
#
# No, but in case good optimalization they will very similar

# %% [markdown]
# ## 5. Suppose you use Batch Gradient Descent and you plot the validation error at every epoch. If you notice that the validation error consistently goes up, what is likely going on? How can you fix this?
#
# The one possibility is that the learning rate is too high and it should be reduce.

# %% [markdown]
# ## 6. Is it a good idea to stop Mini-batch Gradient Descent immediately when the validation error goes up?
#
# No due their random nature

# %% [markdown]
# ## 7. Which Gradient Descent algorithm (among those we discussed) will reach the vicinity of the optimal solution the fastest? Which will actually converge? How can you make the others converge as well?
#
# Stochastic Gradient Descent is the most fastest

# %% [markdown]
# ## 8. Suppose you are using Polynomial Regression. You plot the learning curves and you notice that there is a large gap between the training error and the validation error. What is happening? What are three ways to solve this?
#
# It means that model is overfitted. One solution is to reduce model degree and another one is to use same regulations: l2 (Ridge) or l1 (Lasso) to cost function. Lastly it is nice to try increase the size of training set

# %% [markdown]
# ## 9. Suppose you are using Ridge Regression and you notice that the training error and the validation error are almost equal and fairly high. Would you say that the model suffers from high bias or high variance? Should you increase the regularization hyperparameter α or reduce it?
#
# Model has high bias, so it means that it underfits. To resolve this problem try reducing the hyperparameter alpha

# %% [markdown]
# ## 10. Why would you want to use: Ridge Regression instead of Linear Regression? Lasso instead of Ridge Regression Elastic Net instead of Lasso?
#
# - A model with regulation typically works better
# - Lasso Regulation push weights to exactly zero when Ridge Regression minimalize it
# - Elastic Net is generally preferred over Lasso since Lasso may behave erratically in some cases (when several features are strongly correlated or when there are more features than training instances).

# %% [markdown]
# ## 11. Suppose you want to classify pictures as outdoor/indoor and daytime/nighttime. Should you implement two Logistic Regression classifiers or one Softmax Regression classifier?
#
# Two
